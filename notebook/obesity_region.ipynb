# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df_pop_reg = pd.read_csv ('../data/pop_region.csv')

# %%
df_pop_reg
# Out:
#      Country Name Country Code        1960        1961        1962  \
# 0           Aruba          ABW     54211.0     55438.0     56225.0
# 1     Afghanistan          AFG   8996973.0   9169410.0   9351441.0
# 2          Angola          AGO   5454933.0   5531472.0   5608539.0
# 3         Albania          ALB   1608800.0   1659800.0   1711319.0
# 4         Andorra          AND     13411.0     14375.0     15370.0
# ..            ...          ...         ...         ...         ...
# 259        Kosovo          XKX    947000.0    966000.0    994000.0
# 260   Yemen, Rep.          YEM   5315355.0   5393036.0   5473671.0
# 261  South Africa          ZAF  17099840.0  17524533.0  17965725.0
# 262        Zambia          ZMB   3070776.0   3164329.0   3260650.0
# 263      Zimbabwe          ZWE   3776681.0   3905034.0   4039201.0
#
#            1963        1964        1965        1966        1967  ...  \
# 0       56695.0     57032.0     57360.0     57715.0     58055.0  ...
# ...

# %% [markdown]
# ## drop row 0 & 1

# %%
df_pop_reg.drop(df_pop_reg.index[0:2], inplace = True)

# %%
df_pop_reg = df_pop_reg.reset_index(drop=True)

# %%
df_pop_reg.shape
# Out:
# (8, 127)

# %% [markdown]
# ## Rename the first column

# %%
df_pop = df_pop_reg.rename(columns = {'Unnamed: 0': 'countries'})

# %%
df_pop_reg
# Out:
#                countries              2016            2016.1  \
# 0             WHO region        Both sexes              Male
# 1                 Global  13.1 [12.4-13.9]  11.1 [10.2-12.2]
# 2                 Africa   10.6 [9.6-11.7]     5.6 [4.5-6.8]
# 3               Americas  28.6 [26.6-30.5]  25.9 [23.2-28.8]
# 4        South-East Asia     4.7 [3.9-5.6]     3.3 [2.4-4.3]
# 5                 Europe  23.3 [21.7-24.9]  21.9 [19.8-24.1]
# 6  Eastern Mediterranean  20.8 [19.1-22.6]  15.7 [13.5-18.1]
# 7        Western Pacific     6.4 [5.2-7.7]     6.0 [4.4-8.0]
#
#              2016.2              2015            2015.1            2015.2  \
# 0            Female        Both sexes              Male            Female
# 1  15.1 [14.0-16.2]  12.8 [12.1-13.5]   10.8 [9.9-11.7]  14.7 [13.8-15.7]
# 2  15.3 [13.6-17.1]   10.3 [9.3-11.3]     5.3 [4.4-6.4]  14.9 [13.4-16.5]
# 3  31.0 [28.2-33.7]  28.0 [26.2-29.8]  25.4 [22.8-28.0]  30.5 [27.9-33.1]
# ...

# %% [markdown]
# # change the orientation of the df

# %%
df_pop_reg = df_pop_reg.T.reset_index()

# %%
df_pop_reg
# Out:
#          index            0                 1                 2  \
# 0    countries   WHO region            Global            Africa
# 1         2016   Both sexes  13.1 [12.4-13.9]   10.6 [9.6-11.7]
# 2       2016.1         Male  11.1 [10.2-12.2]     5.6 [4.5-6.8]
# 3       2016.2       Female  15.1 [14.0-16.2]  15.3 [13.6-17.1]
# 4         2015   Both sexes  12.8 [12.1-13.5]   10.3 [9.3-11.3]
# ..         ...          ...               ...               ...
# 122     1976.1         Male     3.0 [2.4-3.8]     0.6 [0.3-1.2]
# 123     1976.2       Female     6.4 [5.3-7.6]     3.5 [2.3-4.9]
# 124       1975   Both sexes     4.7 [4.0-5.4]     2.0 [1.4-2.8]
# 125     1975.1         Male     2.9 [2.2-3.7]     0.6 [0.3-1.1]
# 126     1975.2       Female     6.3 [5.1-7.5]     3.3 [2.2-4.8]
#
#                     3                4                 5  \
# 0            Americas  South-East Asia            Europe
# 1    28.6 [26.6-30.5]    4.7 [3.9-5.6]  23.3 [21.7-24.9]
# ...

# %% [markdown]
# # give the first row, the name of the second row

# %%
df_pop_reg.rename(columns=df_pop_reg.iloc[0], inplace = True)

# %%
df_pop_reg
# Out:
#      countries   WHO region            Global            Africa  \
# 0    countries   WHO region            Global            Africa
# 1         2016   Both sexes  13.1 [12.4-13.9]   10.6 [9.6-11.7]
# 2       2016.1         Male  11.1 [10.2-12.2]     5.6 [4.5-6.8]
# 3       2016.2       Female  15.1 [14.0-16.2]  15.3 [13.6-17.1]
# 4         2015   Both sexes  12.8 [12.1-13.5]   10.3 [9.3-11.3]
# ..         ...          ...               ...               ...
# 122     1976.1         Male     3.0 [2.4-3.8]     0.6 [0.3-1.2]
# 123     1976.2       Female     6.4 [5.3-7.6]     3.5 [2.3-4.9]
# 124       1975   Both sexes     4.7 [4.0-5.4]     2.0 [1.4-2.8]
# 125     1975.1         Male     2.9 [2.2-3.7]     0.6 [0.3-1.1]
# 126     1975.2       Female     6.3 [5.1-7.5]     3.3 [2.2-4.8]
#
#              Americas  South-East Asia            Europe  \
# 0            Americas  South-East Asia            Europe
# 1    28.6 [26.6-30.5]    4.7 [3.9-5.6]  23.3 [21.7-24.9]
# ...
