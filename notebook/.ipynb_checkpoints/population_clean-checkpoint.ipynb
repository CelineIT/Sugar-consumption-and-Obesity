# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df_pop = pd.read_csv ('../data/population_clean.csv')
df_pop.head()
# Out:
#   Country Name Country Code  year  population
# 0        Aruba          ABW  1960     54211.0
# 1        Aruba          ABW  1961     55438.0
# 2        Aruba          ABW  1962     56225.0
# 3        Aruba          ABW  1963     56695.0
# 4        Aruba          ABW  1964     57032.0

# %%
df_pop.shape
# Out:
# (15128, 4)

# %%
df_pop
# Out:
#       Country Name Country Code  year  population
# 0            Aruba          ABW  1960     54211.0
# 1            Aruba          ABW  1961     55438.0
# 2            Aruba          ABW  1962     56225.0
# 3            Aruba          ABW  1963     56695.0
# 4            Aruba          ABW  1964     57032.0
# ...            ...          ...   ...         ...
# 15123     Zimbabwe          ZWE  2016  14030390.0
# 15124     Zimbabwe          ZWE  2017  14236745.0
# 15125     Zimbabwe          ZWE  2018  14439018.0
# 15126     Zimbabwe          ZWE  2019  14645468.0
# 15127     Zimbabwe          ZWE  2020         0.0
#
# [15128 rows x 4 columns]

# %%
df_pop.sort_values(by = 'population', ascending = False).head(50)
# Out:
#       Country Name Country Code  year    population
# 14760        World          WLD  2019  7.673534e+09
# 14759        World          WLD  2018  7.591945e+09
# 14758        World          WLD  2017  7.509074e+09
# 14757        World          WLD  2016  7.424286e+09
# 14756        World          WLD  2015  7.338965e+09
# 14755        World          WLD  2014  7.254227e+09
# 14754        World          WLD  2013  7.169638e+09
# 14753        World          WLD  2012  7.085762e+09
# 14752        World          WLD  2011  7.002860e+09
# 14751        World          WLD  2010  6.921872e+09
# 14750        World          WLD  2009  6.839574e+09
# 14749        World          WLD  2008  6.756918e+09
# 14748        World          WLD  2007  6.674204e+09
# 14747        World          WLD  2006  6.592735e+09
# 14746        World          WLD  2005  6.511748e+09
# 14745        World          WLD  2004  6.431552e+09
# 14744        World          WLD  2003  6.351882e+09
# ...
