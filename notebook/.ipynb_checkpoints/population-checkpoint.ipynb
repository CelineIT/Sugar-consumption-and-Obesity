# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df_pop1 = pd.read_csv ('../data/population.csv')
df_pop1.head()
# Out:
#   Country Name Country Code       1960       1961       1962       1963  \
# 0        Aruba          ABW    54211.0    55438.0    56225.0    56695.0
# 1  Afghanistan          AFG  8996973.0  9169410.0  9351441.0  9543205.0
# 2       Angola          AGO  5454933.0  5531472.0  5608539.0  5679458.0
# 3      Albania          ALB  1608800.0  1659800.0  1711319.0  1762621.0
# 4      Andorra          AND    13411.0    14375.0    15370.0    16412.0
#
#         1964       1965        1966        1967  ...        2011        2012  \
# 0    57032.0    57360.0     57715.0     58055.0  ...    102046.0    102560.0
# 1  9744781.0  9956320.0  10174836.0  10399926.0  ...  30117413.0  31161376.0
# 2  5735044.0  5770570.0   5781214.0   5774243.0  ...  24220661.0  25107931.0
# 3  1814135.0  1864791.0   1914573.0   1965598.0  ...   2905195.0   2900401.0
# 4    17469.0    18549.0     19647.0     20758.0  ...     83747.0     82427.0
#
# ...

# %% [markdown]
# ## order by countries with the highest population in 2019

# %%
df_pop1.sort_values(by = '2019', ascending = False).head(20)
# Out:
#                                     Country Name Country Code          1960  \
# 257                                        World          WLD  3.031438e+09
# 101                             IDA & IBRD total          IBT  2.299245e+09
# 138                          Low & middle income          LMY  2.252173e+09
# 154                                Middle income          MIC  2.108438e+09
# 100                                    IBRD only          IBD  1.919643e+09
# 60                    Early-demographic dividend          EAR  9.800034e+08
# 137                          Lower middle income          LMC  8.762158e+08
# 247                          Upper middle income          UMC  1.232222e+09
# 61                           East Asia & Pacific          EAS  1.040958e+09
# 140                    Late-demographic dividend          LTE  1.096903e+09
# 59   East Asia & Pacific (excluding high income)          EAP  8.948757e+08
# ...

# %% [markdown]
# # change the orientation of the df

# %%
df_pop = df_pop.T.reset_index()

# %%
df_pop
# Out:
#             index            1            2            3            4  \
# 0    Country Name         1960         1961         1962         1963
# 1           Aruba        54211        55438        56225        56695
# 2     Afghanistan  8.99697e+06  9.16941e+06  9.35144e+06  9.54320e+06
# 3          Angola  5.45493e+06  5.53147e+06  5.60854e+06  5.67946e+06
# 4         Albania   1.6088e+06   1.6598e+06  1.71132e+06  1.76262e+06
# ..            ...          ...          ...          ...          ...
# 260        Kosovo       947000       966000       994000    1.022e+06
# 261   Yemen, Rep.  5.31536e+06  5.39304e+06  5.47367e+06  5.55677e+06
# 262  South Africa  1.70998e+07  1.75245e+07  1.79657e+07  1.84232e+07
# 263        Zambia  3.07078e+06  3.16433e+06  3.26065e+06   3.3601e+06
# 264      Zimbabwe  3.77668e+06  3.90503e+06   4.0392e+06  4.17873e+06
#
#                5            6            7            8            9  ...  \
# ...

# %% [markdown]
# # give the first row, the name of the second row

# %%
df_pop.rename(columns=df_pop.iloc[0], inplace = True)

# %%
df_pop.drop(df_pop.index[0:1], inplace= True)

# %%
df_pop
# Out:
#      Country Name         1960         1961         1962         1963  \
# 1           Aruba        54211        55438        56225        56695
# 2     Afghanistan  8.99697e+06  9.16941e+06  9.35144e+06  9.54320e+06
# 3          Angola  5.45493e+06  5.53147e+06  5.60854e+06  5.67946e+06
# 4         Albania   1.6088e+06   1.6598e+06  1.71132e+06  1.76262e+06
# 5         Andorra        13411        14375        15370        16412
# ..            ...          ...          ...          ...          ...
# 260        Kosovo       947000       966000       994000    1.022e+06
# 261   Yemen, Rep.  5.31536e+06  5.39304e+06  5.47367e+06  5.55677e+06
# 262  South Africa  1.70998e+07  1.75245e+07  1.79657e+07  1.84232e+07
# 263        Zambia  3.07078e+06  3.16433e+06  3.26065e+06   3.3601e+06
# 264      Zimbabwe  3.77668e+06  3.90503e+06   4.0392e+06  4.17873e+06
#
#             1964         1965         1966         1967         1968  ...  \
# ...

# %% [markdown]
# ## subset China population

# %%
df_china = df_pop1[df_pop1['Country Name'] == 'China']
df_china
# Out:
#    Country Name Country Code         1960         1961         1962  \
# 38        China          CHN  667070000.0  660330000.0  665770000.0
#
#            1963         1964         1965         1966         1967  ...  \
# 38  682335000.0  698355000.0  715185000.0  735400000.0  754550000.0  ...
#
#             2011          2012          2013          2014          2015  \
# 38  1.344130e+09  1.350695e+09  1.357380e+09  1.364270e+09  1.371220e+09
#
#             2016          2017          2018          2019  2020
# 38  1.378665e+09  1.386395e+09  1.392730e+09  1.397715e+09   NaN
#
# [1 rows x 63 columns]

# %%
df_china = df_china.T.reset_index()

# %%
df_china.rename(columns=df_china.iloc[1], inplace = True)
df_china.drop(df_china.index[0:2], inplace= True)
df_china = df_china.rename(columns = {'Country Code': 'years', 'CHN':'value'})

# %%
df_china
# Out:
#    years        value
# 2   1960   6.6707e+08
# 3   1961   6.6033e+08
# 4   1962   6.6577e+08
# 5   1963  6.82335e+08
# 6   1964  6.98355e+08
# ..   ...          ...
# 58  2016  1.37866e+09
# 59  2017   1.3864e+09
# 60  2018  1.39273e+09
# 61  2019  1.39772e+09
# 62  2020          NaN
#
# [61 rows x 2 columns]

# %% [markdown]
# ## plot world population

# %%
plt.bar(df_china.years, df_china.value, linewidth=2)
plt.rcParams["figure.figsize"] = [15,10]
plt.xlabel('Years')
plt.xticks(rotation = 90)
plt.axhline(y=1.39772e+09, linestyle='-', color='red', label = '2019')
plt.ylabel('population')
plt.title('India population from 1960 to 2019', size = 30)
plt.show()

# %% [markdown]
# ## subset India population

# %%
df_india = df_pop1[df_pop1['Country Name'] == 'India']
df_india
# Out:
#     Country Name Country Code         1960         1961         1962  \
# 107        India          IND  450547679.0  459642165.0  469077190.0
#
#             1963         1964         1965         1966         1967  ...  \
# 107  478825608.0  488848135.0  499123324.0  509631500.0  520400576.0  ...
#
#              2011          2012          2013          2014          2015  \
# 107  1.250289e+09  1.265783e+09  1.280846e+09  1.295604e+09  1.310152e+09
#
#              2016          2017          2018          2019  2020
# 107  1.324510e+09  1.338659e+09  1.352617e+09  1.366418e+09   NaN
#
# [1 rows x 63 columns]

# %% [markdown]
# ## subset World population

# %%
df_world = df_pop1[df_pop1['Country Name'] == 'World']
df_world
# Out:
#     Country Name Country Code          1960          1961          1962  \
# 257        World          WLD  3.031438e+09  3.072481e+09  3.125457e+09
#
#              1963          1964          1965          1966          1967  \
# 257  3.190564e+09  3.256065e+09  3.322973e+09  3.393032e+09  3.462460e+09
#
#      ...          2011          2012          2013          2014  \
# 257  ...  7.002860e+09  7.085762e+09  7.169638e+09  7.254227e+09
#
#              2015          2016          2017          2018          2019  \
# 257  7.338965e+09  7.424286e+09  7.509074e+09  7.591945e+09  7.673534e+09
#
#      2020
# 257   NaN
#
# [1 rows x 63 columns]

# %%
df_world = df_world.T.reset_index()

# %%
df_world.rename(columns=df_world.iloc[1], inplace = True)
df_world.drop(df_world.index[0:2], inplace= True)
df_world = df_world.rename(columns = {'Country Code': 'years', 'WLD':'value'})

# %%
df_world
# Out:
#    years        value
# 2   1960  3.03144e+09
# 3   1961  3.07248e+09
# 4   1962  3.12546e+09
# 5   1963  3.19056e+09
# 6   1964  3.25606e+09
# ..   ...          ...
# 58  2016  7.42429e+09
# 59  2017  7.50907e+09
# 60  2018  7.59195e+09
# 61  2019  7.67353e+09
# 62  2020          NaN
#
# [61 rows x 2 columns]

# %% [markdown]
# ## plot world population

# %%
plt.bar(df_world.years, df_world.value, linewidth=2)
plt.rcParams["figure.figsize"] = [15,10]
plt.xlabel('Years')
plt.xticks(rotation = 90)
plt.axhline(y=7.67353e+09, linestyle='-', color='red', label = '2019')
plt.ylabel('population')
plt.title('World population from 1960 to 2019', size = 30)
plt.show()
